# %%
import pandas as pd

# %%
n=pd.read_csv('/content/n.csv',sep='|')
n.head()
# Out:
#                                        journal_title  \
# 0  NETNOMICS: Economic Research and Electronic Ne...
# 1  NETNOMICS: Economic Research and Electronic Ne...
# 2  NETNOMICS: Economic Research and Electronic Ne...
# 3  NETNOMICS: Economic Research and Electronic Ne...
# 4  NETNOMICS: Economic Research and Electronic Ne...
#
#                                        article_title  \
# 0  Market interaction structure and equilibrium p...
# 1  Unobserved preferences and dynamic platform pr...
# 2      BidPacket: trading bandwidth in public spaces
# 3  Value of digital information networks: a holon...
# 4  Asymmetric competition and collection rates di...
#
#                                         article_link
# 0  https://link.springer.com/article/10.1007/s110...
# 1  https://link.springer.com/article/10.1007/s110...
# 2  https://link.springer.com/article/10.1007/s110...
# 3  https://link.springer.com/article/10.1007/s110...
# 4  https://link.springer.com/article/10.1007/s110...

# %%
o=pd.read_csv('/content/o.csv',sep='|')
o.head()
# Out:
#   journal_title                                      article_title  \
# 0      OPSEARCH  Deriving priority vector from pairwise compari...
# 1      OPSEARCH  Heuristics for the shelf space allocation problem
# 2      OPSEARCH  Multi-objective model for perishable food logi...
# 3      OPSEARCH  Implementing fries model for the fixed lifetim...
# 4   OR Spectrum  Two-stage stochastic formulation for relief op...
#
#                                         article_link
# 0  https://link.springer.com/article/10.1007/s125...
# 1  https://link.springer.com/article/10.1007/s125...
# 2  https://link.springer.com/article/10.1007/s125...
# 3  https://link.springer.com/article/10.1007/s125...
# 4  https://link.springer.com/article/10.1007/s002...

# %%
p=pd.read_csv('/content/p.csv',sep='|')
p.head()
# Out:
#                                        journal_title  \
# 0  PFG – Journal of Photogrammetry, Remote Sensin...
# 1  PFG – Journal of Photogrammetry, Remote Sensin...
# 2  PFG – Journal of Photogrammetry, Remote Sensin...
# 3  PFG – Journal of Photogrammetry, Remote Sensin...
# 4  PFG – Journal of Photogrammetry, Remote Sensin...
#
#                                        article_title  \
# 0  VOX2BIM+ - A Fast and Robust Approach for Auto...
# 1  Automation Strategies for the Photogrammetric ...
# 2               Semantic Real-Time Mapping with UAVs
# 3  A Globally Applicable Method for NDVI Estimati...
# 4  Uncovering Early Traces of Bark Beetle Induced...
#
#                                         article_link
# 0  https://link.springer.com/article/10.1007/s410...
# 1  https://link.springer.com/article/10.1007/s410...
# 2  https://link.springer.com/article/10.1007/s410...
# 3  https://link.springer.com/article/10.1007/s410...
# 4  https://link.springer.com/article/10.1007/s410...

# %%
q=pd.read_csv('/content/q.csv',sep='|')
q.head()
# Out:
#            journal_title                                      article_title  \
# 0  Qualitative Sociology  Privileged but not in Power: How Asian America...
# 1  Qualitative Sociology  “Horrible Slime Stories” When Serving Victims:...
# 2  Qualitative Sociology  “Welcome to the Revolution”: Promoting Generat...
# 3  Qualitative Sociology  “It’s the Seeing and Feeling”: How Embodied an...
# 4  Qualitative Sociology  Code Ethnography and the Materiality of Power ...
#
#                                         article_link
# 0  https://link.springer.com/article/10.1007/s111...
# 1  https://link.springer.com/article/10.1007/s111...
# 2  https://link.springer.com/article/10.1007/s111...
# 3  https://link.springer.com/article/10.1007/s111...
# 4  https://link.springer.com/article/10.1007/s111...

# %%
r=pd.read_csv('/content/r.csv',sep='|')
r.head()
# Out:
#               journal_title  \
# 0  Race and Social Problems
# 1  Race and Social Problems
# 2  Race and Social Problems
# 3  Race and Social Problems
# 4  Race and Social Problems
#
#                                        article_title  \
# 0  Local TV News Coverage of Racial Disparities i...
# 1  Racial Discrimination, Black Identity, and Cri...
# 2  Raising “Antiracist Disruptors”: Illuminating ...
# 3  Do Ethnic-Racial Identity Dimensions Moderate ...
# 4  Values and Attitudes Toward Immigrants Among S...
#
#                                         article_link
# 0  https://link.springer.com/article/10.1007/s125...
# 1  https://link.springer.com/article/10.1007/s125...
# 2  https://link.springer.com/article/10.1007/s125...
# 3  https://link.springer.com/article/10.1007/s125...
# 4  https://link.springer.com/article/10.1007/s125...

# %%
s=pd.read_csv('/content/s.csv',sep='|')
s.head()
# Out:
#   journal_title                                      article_title  \
# 0        SERIEs  Attitudes towards single parents’ children in ...
# 1        SERIEs  Education and internal migration: evidence fro...
# 2        SERIEs  Housing prices in Spain: convergence or decoup...
# 3        SERIEs  The price effects of reducing payment card int...
# 4        SERIEs  Properties of least squares estimator in estim...
#
#                                         article_link
# 0  https://link.springer.com/article/10.1007/s132...
# 1  https://link.springer.com/article/10.1007/s132...
# 2  https://link.springer.com/article/10.1007/s132...
# 3  https://link.springer.com/article/10.1007/s132...
# 4  https://link.springer.com/article/10.1007/s132...

# %%
t=pd.read_csv('/content/t.csv',sep='|')
t.head()
# Out:
#   journal_title                                      article_title  \
# 0          TEST  A general class of shock models with dependent...
# 1          TEST  Comments on: Nonparametric estimation in mixtu...
# 2          TEST  Comments on: Nonparametric estimation in mixtu...
# 3          TEST  Correction: Novel specification tests for sync...
# 4          TEST  Novel specification tests for synchronous addi...
#
#                                         article_link
# 0  https://link.springer.com/article/10.1007/s117...
# 1  https://link.springer.com/article/10.1007/s117...
# 2  https://link.springer.com/article/10.1007/s117...
# 3  https://link.springer.com/article/10.1007/s117...
# 4  https://link.springer.com/article/10.1007/s117...

# %%
u=pd.read_csv('/content/u.csv',sep='|')
u.head()
# Out:
#                                  journal_title  \
# 0  Universal Access in the Information Society
# 1  Universal Access in the Information Society
# 2  Universal Access in the Information Society
# 3  Universal Access in the Information Society
# 4  Universal Access in the Information Society
#
#                                        article_title  \
# 0  Barriers and wellbeing-oriented enablers of in...
# 1  The use of accessibility metadata in e-learnin...
# 2  Designing accessible visual programming tools ...
# 3  Investigating socially assistive systems from ...
# 4  Tailoring assistive smart glasses according to...
#
#                                         article_link
# 0  https://link.springer.com/article/10.1007/s102...
# 1  https://link.springer.com/article/10.1007/s102...
# 2  https://link.springer.com/article/10.1007/s102...
# 3  https://link.springer.com/article/10.1007/s102...
# 4  https://link.springer.com/article/10.1007/s102...

# %%
v=pd.read_csv('/content/v.csv',sep='|')
v.head()
# Out:
#                                        journal_title  \
# 0  VOLUNTAS: International Journal of Voluntary a...
# 1  VOLUNTAS: International Journal of Voluntary a...
# 2  VOLUNTAS: International Journal of Voluntary a...
# 3  VOLUNTAS: International Journal of Voluntary a...
# 4  VOLUNTAS: International Journal of Voluntary a...
#
#                                        article_title  \
# 0  Are Mediterranean Nonprofits Adopting the Soci...
# 1  Assessing the ‘Why’ in Volunteering for Refuge...
# 2  Nonprofits for Cohesive Cities: Neighborhood C...
# 3  Exploring the Effects of Volunteering on the S...
# 4  The Mediating Role of Migrant Community-Based ...
#
#                                         article_link
# 0  https://link.springer.com/article/10.1007/s112...
# 1  https://link.springer.com/article/10.1007/s112...
# 2  https://link.springer.com/article/10.1007/s112...
# 3  https://link.springer.com/article/10.1007/s112...
# 4  https://link.springer.com/article/10.1007/s112...

# %%
w=pd.read_csv('/content/w.csv',sep='|')
w.head()
# Out:
#                      journal_title  \
# 0  WMU Journal of Maritime Affairs
# 1  WMU Journal of Maritime Affairs
# 2  WMU Journal of Maritime Affairs
# 3  WMU Journal of Maritime Affairs
# 4  WMU Journal of Maritime Affairs
#
#                                        article_title  \
# 0                                    Guest editorial
# 1  Formative assessment in maritime simulator-bas...
# 2  Integrating motivated goal achievement in mari...
# 3  A human-centred design approach for the develo...
# 4  Theorizing seafarers’ participation and learni...
#
#                                         article_link
# 0  https://link.springer.com/article/10.1007/s134...
# 1  https://link.springer.com/article/10.1007/s134...
# 2  https://link.springer.com/article/10.1007/s134...
# 3  https://link.springer.com/article/10.1007/s134...
# 4  https://link.springer.com/article/10.1007/s134...

# %%
z=pd.read_csv('/content/z.csv',sep='|')
z.head()
# Out:
#                  journal_title  \
# 0  ZDM – Mathematics Education
# 1  ZDM – Mathematics Education
# 2  ZDM – Mathematics Education
# 3  ZDM – Mathematics Education
# 4  ZDM – Mathematics Education
#
#                                        article_title  \
# 0  Mathematics education research on language and...
# 1  Teachers’ practices and resources in the Hunga...
# 2  An anthropological point of view: exploring th...
# 3  Resources in translation: towards a conceptual...
# 4  Teaching the concept of zero in a Malawi prima...
#
#                                         article_link
# 0  https://link.springer.com/article/10.1007/s118...
# 1  https://link.springer.com/article/10.1007/s118...
# 2  https://link.springer.com/article/10.1007/s118...
# 3  https://link.springer.com/article/10.1007/s118...
# 4  https://link.springer.com/article/10.1007/s118...

# %%
df=n.append([o,p,q,r,s,t,u,v,w,z])
df.shape
# Out:
# <ipython-input-16-bc4ca6d0034a>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=n.append([o,p,q,r,s,t,u,v,w,z])
# (91980, 3)

# %%
display(df)
# Out:
#                                           journal_title  \
# 0     NETNOMICS: Economic Research and Electronic Ne...
# 1     NETNOMICS: Economic Research and Electronic Ne...
# 2     NETNOMICS: Economic Research and Electronic Ne...
# 3     NETNOMICS: Economic Research and Electronic Ne...
# 4     NETNOMICS: Economic Research and Electronic Ne...
# ...                                                 ...
# 2611                                      Zoomorphology
# 2612                                      Zoomorphology
# 2613                                      Zoomorphology
# 2614                                      Zoomorphology
# 2615                                      Zoomorphology
#
#                                           article_title  \
# 0     Market interaction structure and equilibrium p...
# 1     Unobserved preferences and dynamic platform pr...
# 2         BidPacket: trading bandwidth in public spaces
# 3     Value of digital information networks: a holon...
# ...

# %%
df['article_title'] = df['article_title'].str.replace(r'[^a-zA-Z0-9\s]', '')
df.head()
# Out:
# <ipython-input-18-9873cd3391ce>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['article_title'] = df['article_title'].str.replace(r'[^a-zA-Z0-9\s]', '')
#                                        journal_title  \
# 0  NETNOMICS: Economic Research and Electronic Ne...
# 1  NETNOMICS: Economic Research and Electronic Ne...
# 2  NETNOMICS: Economic Research and Electronic Ne...
# 3  NETNOMICS: Economic Research and Electronic Ne...
# 4  NETNOMICS: Economic Research and Electronic Ne...
#
#                                        article_title  \
# 0  Market interaction structure and equilibrium p...
# 1  Unobserved preferences and dynamic platform pr...
# 2       BidPacket trading bandwidth in public spaces
# 3  Value of digital information networks a holoni...
# 4  Asymmetric competition and collection rates di...
#
#                                         article_link
# 0  https://link.springer.com/article/10.1007/s110...
# ...

# %%
df.to_csv('n-z.csv')
