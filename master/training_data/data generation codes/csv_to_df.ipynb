# %%
import pandas as pd
df=pd.read_csv("/content/merged.csv")
df
# Out:
# <ipython-input-11-279c31236f15>:2: DtypeWarning: Columns (3,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/merged.csv")
#                                                Item Title  \
# 0       Correction to: Strong field physics pursued wi...
# 1                        Correction: News and Views (3&4)
# 2               Correction: Time reversal and reciprocity
# 3                                    News and Views (7&8)
# 4       Ultrasound detection using a thermal-assisted ...
# ...                                                   ...
# 295251  Is there a relationship between the morphology...
# 295252  From micropterism to hyperpterism: recognition...
# 295253  The structure of extremely long mouthparts in ...
# 295254  Morphological study of the antennal sensilla i...
# 295255  Histological, histochemical and ultrastructura...
#
#         "Publication Title"   "Book Series Title" Journal Volume  \
# ...
