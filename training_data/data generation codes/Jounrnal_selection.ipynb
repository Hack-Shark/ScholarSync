# %%
import pandas as pd
main=pd.read_csv('springer_data.csv')
main=main[main['Language']=='en']
main=main.drop(['Language','Item DOI'],axis=1)
main.head()
# Out:
#                                           Item Title Publication Title  \
# 0  Correction to: Strong field physics pursued wi...    AAPPS Bulletin
# 1          Correction: Time reversal and reciprocity    AAPPS Bulletin
# 2  Ultrasound detection using a thermal-assisted ...    AAPPS Bulletin
# 3  Relativistic density functional theory in nucl...    AAPPS Bulletin
# 4                      Muon cooling and acceleration    AAPPS Bulletin
#
#                                              Authors  Publication Year  \
# 0  Vishwa Bandhu PathakSeong Ku LeeKi Hong PaeCal...              2021
# 1                Olivier SigwarthChristian Miniatura              2022
# 2  Jia-Wei MengPei-Ji ZhangShui-Jing TangYun-Feng...              2022
# 3                               Jie MengPengwei Zhao              2021
# 4                                      Masashi Otani              2022
#
#                                                  URL  \
# 0  http://link.springer.com/article/10.1007/s4367...
# 1  http://link.springer.com/article/10.1007/s4367...
# 2  http://link.springer.com/article/10.1007/s4367...
# 3  http://link.springer.com/article/10.1007/s4367...
# 4  http://link.springer.com/article/10.1007/s4367...
#
#                                             keywords
# 0  AAPPS Bulletin Atomic Molecular Optical and Pl...
# 1  AAPPS Bulletin Atomic Molecular Optical and Pl...
# 2  AAPPS Bulletin Atomic Molecular Optical and Pl...
# 3  AAPPS Bulletin Atomic Molecular Optical and Pl...
# 4  AAPPS Bulletin Atomic Molecular Optical and Pl...

# %%
main.describe()
# Out:
#        Publication Year
# count     279624.000000
# mean        2018.662740
# std            4.398261
# min         1971.000000
# 25%         2017.000000
# 50%         2020.000000
# 75%         2022.000000
# max         2023.000000

# %%
main.reset_index()
main.rename(columns={'index': 'ITem_ID'}, inplace=True)
main.head()
# Out:
#                                           Item Title Publication Title  \
# 0  Correction to: Strong field physics pursued wi...    AAPPS Bulletin
# 1          Correction: Time reversal and reciprocity    AAPPS Bulletin
# 2  Ultrasound detection using a thermal-assisted ...    AAPPS Bulletin
# 3  Relativistic density functional theory in nucl...    AAPPS Bulletin
# 4                      Muon cooling and acceleration    AAPPS Bulletin
#
#                                              Authors  Publication Year  \
# 0  Vishwa Bandhu PathakSeong Ku LeeKi Hong PaeCal...              2021
# 1                Olivier SigwarthChristian Miniatura              2022
# 2  Jia-Wei MengPei-Ji ZhangShui-Jing TangYun-Feng...              2022
# 3                               Jie MengPengwei Zhao              2021
# 4                                      Masashi Otani              2022
#
#                                                  URL  \
# 0  http://link.springer.com/article/10.1007/s4367...
# 1  http://link.springer.com/article/10.1007/s4367...
# 2  http://link.springer.com/article/10.1007/s4367...
# 3  http://link.springer.com/article/10.1007/s4367...
# 4  http://link.springer.com/article/10.1007/s4367...
#
#                                             keywords
# 0  AAPPS Bulletin Atomic Molecular Optical and Pl...
# 1  AAPPS Bulletin Atomic Molecular Optical and Pl...
# 2  AAPPS Bulletin Atomic Molecular Optical and Pl...
# 3  AAPPS Bulletin Atomic Molecular Optical and Pl...
# 4  AAPPS Bulletin Atomic Molecular Optical and Pl...

# %% [markdown]
# ### Journal Dataframe

# %%
journal_art = main.groupby('Publication Title')['Item Title'].apply(list).reset_index(name='Articles')
journal_art.head()
# Out:
#    Publication Title                                           Articles
# 0     AAPPS Bulletin  [Correction to: Strong field physics pursued w...
# 1  AAPS PharmSciTech  [Correction: Environmental Monitoring for Clos...
# 2                AGE  [The dominant human conjunctival epithelial CD...
# 3       AI & SOCIETY  [Correction to: Dismantling the Chinese Room w...
# 4      AI and Ethics  [Publisher Correction: Convergence of the sour...

# %%
journal_art.set_index(['Publication Title'],inplace=True)
journal_art.head()
# Out:
#                                                             Articles
# Publication Title
# AAPPS Bulletin     [Correction to: Strong field physics pursued w...
# AAPS PharmSciTech  [Correction: Environmental Monitoring for Clos...
# AGE                [The dominant human conjunctival epithelial CD...
# AI & SOCIETY       [Correction to: Dismantling the Chinese Room w...
# AI and Ethics      [Publisher Correction: Convergence of the sour...

# %%
journal_key= main.drop_duplicates(subset=["Publication Title", "keywords"], keep='first')
journal_key=journal_key.drop(['Item Title','Authors','Publication Year','URL'],axis=1)
journal_key.head()
journal_key.set_index(['Publication Title'],inplace=True)

# %%
journal_key.head()
# Out:
#                                                                   keywords
# Publication Title
# AAPPS Bulletin           AAPPS Bulletin Atomic Molecular Optical and Pl...
# AAPS PharmSciTech        AAPS PharmSciTech PharmacologyToxicology Biote...
# AI & SOCIETY                                                           NaN
# AI and Ethics                                                          NaN
# AI in Civil Engineering                                                NaN

# %%
journal_main = pd.concat([journal_key, journal_art], axis=1, join='inner')
journal_main.head()
# Out:
#                                                                   keywords  \
# Publication Title
# AAPPS Bulletin           AAPPS Bulletin Atomic Molecular Optical and Pl...
# AAPS PharmSciTech        AAPS PharmSciTech PharmacologyToxicology Biote...
# AI & SOCIETY                                                           NaN
# AI and Ethics                                                          NaN
# AI in Civil Engineering                                                NaN
#
#                                                                   Articles
# Publication Title
# AAPPS Bulletin           [Correction to: Strong field physics pursued w...
# AAPS PharmSciTech        [Correction: Environmental Monitoring for Clos...
# AI & SOCIETY             [Correction to: Dismantling the Chinese Room w...
# AI and Ethics            [Publisher Correction: Convergence of the sour...
# AI in Civil Engineering  [AI in Civil Engineering, Fusion of thermal an...

# %%
journal_main=journal_main.reset_index()
journal_main.head()
# Out:
#          Publication Title                                           keywords  \
# 0           AAPPS Bulletin  AAPPS Bulletin Atomic Molecular Optical and Pl...
# 1        AAPS PharmSciTech  AAPS PharmSciTech PharmacologyToxicology Biote...
# 2             AI & SOCIETY                                                NaN
# 3            AI and Ethics                                                NaN
# 4  AI in Civil Engineering                                                NaN
#
#                                             Articles
# 0  [Correction to: Strong field physics pursued w...
# 1  [Correction: Environmental Monitoring for Clos...
# 2  [Correction to: Dismantling the Chinese Room w...
# 3  [Publisher Correction: Convergence of the sour...
# 4  [AI in Civil Engineering, Fusion of thermal an...

# %%
def get_paragraph(row):
  ans=''
  for x in row[2]:
    ans=ans+''+x.lower()
  return ans
journal_main['Articles']=journal_main.apply(get_paragraph,axis=1) 
journal_main.head()
# Out:
#          Publication Title                                           keywords  \
# 0           AAPPS Bulletin  AAPPS Bulletin Atomic Molecular Optical and Pl...
# 1        AAPS PharmSciTech  AAPS PharmSciTech PharmacologyToxicology Biote...
# 2             AI & SOCIETY                                                NaN
# 3            AI and Ethics                                                NaN
# 4  AI in Civil Engineering                                                NaN
#
#                                             Articles
# 0  correction to: strong field physics pursued wi...
# 1  correction: environmental monitoring for close...
# 2  correction to: dismantling the chinese room wi...
# 3  publisher correction: convergence of the sourc...
# 4  ai in civil engineeringfusion of thermal and r...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Tokenize and perform POS tagging for each row
journal_main['Tokenized'] = journal_main['Articles'].apply(word_tokenize)
journal_main['Tagged'] = journal_main['Tokenized'].apply(pos_tag)
journal_main['Tags'] = journal_main['Tagged'].apply(lambda x: [word for word, tag in x if tag.startswith('NN') or tag.startswith('JJ')])
journal_main.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
#          Publication Title                                           keywords  \
# 0           AAPPS Bulletin  AAPPS Bulletin Atomic Molecular Optical and Pl...
# 1        AAPS PharmSciTech  AAPS PharmSciTech PharmacologyToxicology Biote...
# 2             AI & SOCIETY                                                NaN
# 3            AI and Ethics                                                NaN
# 4  AI in Civil Engineering                                                NaN
#
#                                             Articles  \
# 0  correction to: strong field physics pursued wi...
# 1  correction: environmental monitoring for close...
# 2  correction to: dismantling the chinese room wi...
# 3  publisher correction: convergence of the sourc...
# 4  ai in civil engineeringfusion of thermal and r...
#
#                                            Tokenized  \
# 0  [correction, to, :, strong, field, physics, pu...
# 1  [correction, :, environmental, monitoring, for...
# 2  [correction, to, :, dismantling, the, chinese,...
# 3  [publisher, correction, :, convergence, of, th...
# 4  [ai, in, civil, engineeringfusion, of, thermal...
#
#                                               Tagged  \
# 0  [(correction, NN), (to, TO), (:, :), (strong, ...
# 1  [(correction, NN), (:, :), (environmental, JJ)...
# 2  [(correction, NN), (to, TO), (:, :), (dismantl...
# 3  [(publisher, NN), (correction, NN), (:, :), (c...
# 4  [(ai, NN), (in, IN), (civil, JJ), (engineering...
#
#                                                 Tags
# 0  [correction, strong, field, physics, petawatt,...
# 1  [correction, environmental, monitoring, closed...
# 2  [correction, chinese, room, linguistic, tools,...
# 3  [publisher, correction, convergence, source, c...
# 4  [ai, civil, engineeringfusion, thermal, rgb, i...

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
journal_main['Tags'] = journal_main['Tags'].apply(lambda x: [word for word in x if word.lower() not in stop_words])
journal_main.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# journal_main=journal_main.drop(['Articles','Tokenized','Tagged'],axis=1)
backup=journal_main
journal_main.head()
# Out:
#          Publication Title                                           keywords  \
# 0           AAPPS Bulletin  AAPPS Bulletin Atomic Molecular Optical and Pl...
# 1        AAPS PharmSciTech  AAPS PharmSciTech PharmacologyToxicology Biote...
# 2             AI & SOCIETY                                                NaN
# 3            AI and Ethics                                                NaN
# 4  AI in Civil Engineering                                                NaN
#
#                                                 Tags
# 0  [correction, strong, field, physics, petawatt,...
# 1  [correction, environmental, monitoring, closed...
# 2  [correction, chinese, room, linguistic, tools,...
# 3  [publisher, correction, convergence, source, c...
# 4  [ai, civil, engineeringfusion, thermal, rgb, i...

# %%
def get_tags(row):
  ans=''
  for x in row[2]:
    ans=ans+' '+x.lower()
  return ans
def combine_key(row):
  ans=row[2]+' '
  if(isinstance(row[1],str)):
    for x in row[1]:
      ans=ans+''+x.lower()
  return ans
journal_main['Tags']=journal_main.apply(get_tags,axis=1)
journal_main['Tags']=journal_main.apply(combine_key,axis=1)
journal_main.head()
# Out:
#          Publication Title                                           keywords  \
# 0           AAPPS Bulletin  AAPPS Bulletin Atomic Molecular Optical and Pl...
# 1        AAPS PharmSciTech  AAPS PharmSciTech PharmacologyToxicology Biote...
# 2             AI & SOCIETY                                                NaN
# 3            AI and Ethics                                                NaN
# 4  AI in Civil Engineering                                                NaN
#
#                                                 Tags
# 0   correction strong field physics petawatt lase...
# 1   correction environmental monitoring closed ro...
# 2   correction chinese room linguistic tools fram...
# 3   publisher correction convergence source contr...
# 4   ai civil engineeringfusion thermal rgb images...

# %%
journal_main=journal_main.drop(['keywords'],axis=1)
journal_main.head()
# Out:
#          Publication Title                                               Tags
# 0           AAPPS Bulletin   correction strong field physics petawatt lase...
# 1        AAPS PharmSciTech   correction environmental monitoring closed ro...
# 2             AI & SOCIETY   correction chinese room linguistic tools fram...
# 3            AI and Ethics   publisher correction convergence source contr...
# 4  AI in Civil Engineering   ai civil engineeringfusion thermal rgb images...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(journal_main['Tags'])

# %%
user_input = "AI in natural language processing"
user_tfidf = vectorizer.transform([user_input])
cosine_similarities = cosine_similarity(user_tfidf, tfidf_matrix).flatten()
top_recommendations = cosine_similarities.argsort()[::-1][:3]
print(top_recommendations)
for x in top_recommendations:
  print(journal_main['Publication Title'][x])
  print(journal_main['Tags'][x])
  print()
# Out:
# [   3    2 1529]
# AI and Ethics
#  publisher correction convergence source control actual access accounts privacycorrection operationalising ai governance ethics-based auditing industry case studycorrection philosophical foundations digital ethics ai ethics dignitarian approachcorrection ai ethics case animalspublisher correction ai context perspective unique challenges employment research disparate impactpublisher correction fair transparent robust analytics systemsapropos “ speciesist bias ai ai applications discrimination unfair outcomes animals double-edged sword ai ethical adversarial attacks artificial intelligence smart glasses potential benefits ethical privacy concerns ray-ban eu ai act—presidency compromise text select overview comment changes regulationa framework ai ethics applications cybersecurityethical issues delayed adoption artificial intelligence medical imagingtrue uncertainty ethical ai regulatory sandboxes policy tool moral imaginationrawlsian ai fairness loopholespersonality demographic correlates support artificial intelligenceresponsible ai moral responsibility common appreciationai-deploying organizations key ‘ perfect storm ’ ai risksfacial identity protection deep learning technologies application affective computingartificial intelligence ’ promise implementing ethical aiworkplace automation achievement gaps reply legal landscape ai copyright comparative analysis eu chinese approachesmethodology artificial intelligence healthcare systems covid-19 disease xsocietal bias reinforcement machine learning credit perspectivesustainable ai ai sustainability sustainability aithe interrelation data ai ethics context impact assessmentsartificial intelligence research development sustainability centrality explicability research data organizational ai governancegarbage data proposal ethical artificial intelligence sustainability impact risk interpretability explicabilitythe rapid competitive economy machine learning development discussion social risks ai ethics tools purpose ethics human–ai teaming principles perspectivesif conceptual engineering new method ethics ai method moral exemplars virtuous machine clinician ’ role ethical artificial intelligence healthcareai ’ fairness problem understanding wrongful discrimination context automated decision-makingethical risks ai-designed products bespoke surgical tools case studyresponsible innovation anticipation responsiveness case studies algorithms decision support justice security exploration potential unintended undesirable higher-order effectsexplainability fig leaf exploration experts ’ ethical expectations towards machine learning psychiatrycoarse ethics explainable artificial intelligencemoral responsibility productsexplainable machine learning practices opening black box reliable medical aithe ethical issues application artificial intelligence healthcare systematic scoping reviewthe struggle recognition age facial recognition social robotsexplainable ai lacks regulative reasons human decision-making opaquea critique ‘ as–if ’ approach machine ethicstrust trustworthiness ai ethicsresponsibility hybrid societies concepts termsneed speed vehicles capable faster legal speed limits bannedhci alienation autonomy involvement blind spots digital ethicsbias awareness ignorance deep-learning-based face recognitionreplika metaverse moral problem empathy ‘ bit ’ community-in-the-loop towards pluralistic value creation ai or—why needs business ethicsare mistake diagnosis ai diagnostic system responsibility gaps reactive attitudesdisruption technology question artificial computer ethics light ai systems ai gap case ‘ theorized agreement ’ ai public ’ opinion perception artificial intelligence moral standing meaningful human control drones human–machine teaming different ethical perspectivesa new control problem humanoid robots artificial intelligence value controlblind spots ai ethicsalgorithmic decision-making financial services economic normative outcomes consumer intelligent workplace ethical framewor ...
#
# AI & SOCIETY
#  correction chinese room linguistic tools framework concept-application disputescorrection truth social practice digital era iteration persuasioncorrection investing ai social good analysis european national strategiescorrection jumping artistic deep end building catalogue raisonnécorrection dark archives dark age archives artificial intelligence marketing friend foe sustainable consumption correction operative communication project cybersyn intersection information design interface design interaction designthe dissolution condicio humanaai4people people4ai human adaptation worka possibility inappropriate use gender studies human-robot interactionpsychological targeting nudge boost mindful sustainable consumption apocalypse need artificial general intelligenceai ethics review recent publicationscausality poetics grammatology role computation machine ‘ national archive ’ interview john sheridan digital director national archives ‘ nature ’ ‘ artificial ’ description philophonetics expressive therapeutic modality depressiondo people social anxiety anxious robot weedistanalysis news sentiments natural language processing deep learninganthropomorphization humanwashing ai-enabled machinesencountering ethics design workshop nonhuman human artificial intelligence machine learning big data digitalisation human–robot interaction industry epistemic opacity autonomous systems ethical consequencesgender preferences robots equality orientation communication situationsthe epistemic impossibility artificial intelligence take-over democracyperspectives tech industry designer geof iteration built-in goal mobile app designword embeddings bias natural language processing analysis covid-19 open-text opinions distilbert model sentiment categorizationa new standard accident simulations self-driving vehicles waymo ’ results accident simulations artificial intelligence vs covid-19 limitations constraints pitfallsblue collar tie human-centered reformulation ironies automationa free mind transferredwhy possible worlds revelation superintelligencethink ai manifesto futuretowards low-cost machine solutions smessmart soldiers ethical warfareintroduction special issue—critical robotics researchexperiences knowledge functions social acceptance robots exploratory case study japancaring in-between proposal responsible ai robotics contradictions digital modernityexpert views ai narratives ai story crisis technoperformances metaphors performance arts postphenomenology posthermeneutics technology ethics workplace design scorecard australian workplace health safetyartificial intelligence work critical review recent research social sciencesservice robots affective labor sociology labor perspectivethe unwitting labourer humanness ai trainingit ball walk boundary work software developmentai spinoza review law ’ conceptual treatment lethal autonomousmachine invention systems r evolution invention process organic dynamic tool use knowledge base ai ethics engineers ’ practice ethical ai designshould robot best human–robot interaction user experience ethical designartificial intelligence elsi score science technology comparison japan uscan machine think anything new automation ai capitalism commons alternative power concentration big techclinical ai opacity accountability responsibility liabilityconcordance evidence watson oncology decision-support children ’ exposure voice assistants ontological conceptualizations life technologythe internet bodies—alive collective virtual physical future bodies sensesindexing brazilian person cases data distributed repositories webrobot ukiyo-e implications cultural varieties human–robot relationshipshuman–computer interaction tools gameful design critical media ecosystem classification frameworkmoral disagreement artificial intelligencethe rift aesthetics ethics design computational thingssafety requirements policies autonomous machine approach bias discrimination job advertisementsopenness privacy born-digital archives role ai devel ...
#
# Language Policy
#  markus rheindorf ruth wodak eds sociolinguistic perspectives migration control language policy identity belongingthe gentrification two-way dual language programs commentarycorrection bilingualism multilingualism workplace case basque autonomous communityresistance adaptation educational institutions tales estoniafamily language policy retrospect narratives success failure indian–iranian transnational language questions politics scots census scotlandcreative ambiguity service language policy new speakers language ” community-based anishinaabemowin language tek-nologyimplementation acceptance national language policy case dutch new speakers new old languages investigation gap language practices language policyanglonormativity norwegian language education policy educational trajectories immigrant adolescents employers ’ ” voices blue-collar workplaces northern peripherylanguage policy linguistic landscaping contemporary blue-collar workplace dutch–german borderland ‘ new speakers language policy research thematic theoretical contributions fieldblue-collar workplace communicative practices case study construction sites qatardialect language nation years oncritical ethnography language policy global south insights research timor-lestenew speaker parents grassroots policy makers contemporary galicia ideologies management practicesfrom discourses language-in-education policy language practices classroom—a linguistic ethnographic study multi-scalar nature timor-lestecontesting language policy asylum seekers northern periphery story tailor falternative sources data alternative histories standardisationfactors selection standard universals standardisation german relativisersadult literacy classes timor-leste diverse language values practices regions implications language policy-makinglanguage policy ideological clarification theory mindsocietal support educational provisions finnish swedish school system theory practicelanguage test activismperceptions attitudes qatar university students utility arabic english communication education qatarpolicy formation adult migrant language education england national neglect implicationsfrom haugen ’ codification ’ purism role description prescription prescriptivism purism linguistic standardisationofficiality strategic ambiguity language policy exploring migrant experiences andorra luxembourgthe evolution language ideological debates english french multilingual humanitarian organisationlanguage advocacy times securitization neoliberalization network languagerightsstate recognition ‘ languages comparative study sardinian asturian sub-state integration policies migrant new speakers stakeholders language regimesamid signs change language policy ideology power linguistic landscape urban rwandaaffects verbal hygiene impact language activism swedish high schoolgrammar tests policy pedagogical coercion england ’ primary schoolsclaudine chamoreau isabelle léglise eds dynamics contact-induced language change language contact bilingualism series change variation family religious language policy west african muslim communitylinguistic imperialism valid construct relation language policy irish sign languagenormative language policy minority language rights case regional languages system teachers english learners literacy instruction mandatelanguage policy in-migration discursive debates walesfrom bilingualism multilingualism workplace case basque autonomous communityharmony language policy china internet commodification ethnographic look policing irish commercial assetlanguage language-in-education planning multilingual india minoritized language perspectivemother tongue instruction sweden denmarkminority language standardisation role survival linguistic diversitya market commodifiable workers language migration governmentality selfprofessional development programmes teachers majority language medium education lessons comparative studyassertive discourse folk linguistics serbian nationalist discourse cyrilli ...

# %%
journal_main.to_csv('journal_tags.csv')
