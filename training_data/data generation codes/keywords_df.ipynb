# %%
import pandas as pd

# %%
headers = ['journal_title', 'keyowrds', 'abstract'] 

combined_df = pd.read_csv('a_to_z_keywordsdata.csv', sep=';',header=None, names=headers)
combined_df
# Out:
#                                           journal_title  \
# 0                                        AAPPS Bulletin
# 1                                             AAPS Open
# 2                                     AAPS PharmSciTech
# 3     ADHD Attention Deficit and Hyperactivity Disor...
# 4                                            AI SOCIETY
# ...                                                 ...
# 3806                                      Zoomorphology
# 3807                                       Zorg Welzijn
# 3808                               Zorg en Financiering
# 3809                                          Zorgvisie
# 3810                                     Zorgvisie tech
#
#                                                keyowrds  \
# 0     AAPPS Bulletin Atomic Molecular Optical and Pl...
# 1     AAPS Open Pharmaceutical SciencesTechnology Ph...
# 2     AAPS PharmSciTech PharmacologyToxicology Biote...
# 3     ADHD Attention Deficit and Hyperactivity Disor...
# ...

# %%
combined_df.describe()
# Out:
#                         journal_title  \
# count                            3811
# unique                           3807
# top     Journal of Biomedical Science
# freq                                2
#
#                                                  keyowrds  \
# count                                                3759
# unique                                               3758
# top     Journal of Biomedical Science Biomedicine general
# freq                                                    2
#
#                                                  abstract
# count                                                2412
# unique                                               2411
# top     Sankhya the Indian Journal of Statistics is th...
# freq                                                    2

# %%
combined_df.count()
# Out:
# journal_title    3811
# keyowrds         3759
# abstract         2412
# dtype: int64

# %%
combined_df.head(-10)
# Out:
#                                           journal_title  \
# 0                                        AAPPS Bulletin
# 1                                             AAPS Open
# 2                                     AAPS PharmSciTech
# 3     ADHD Attention Deficit and Hyperactivity Disor...
# 4                                            AI SOCIETY
# ...                                                 ...
# 3796   Zeitschrift fr Vergleichende Politikwissenschaft
# 3797             Zeitschrift fr Weiterbildungsforschung
# 3798    Zeitschrift fr angewandte Mathematik und Physik
# 3799  Zeitschrift fr die gesamte Neurologie und Psyc...
# 3800  Zeitschrift fr die gesamte Versicherungswissen...
#
#                                                keyowrds  \
# 0     AAPPS Bulletin Atomic Molecular Optical and Pl...
# 1     AAPS Open Pharmaceutical SciencesTechnology Ph...
# 2     AAPS PharmSciTech PharmacologyToxicology Biote...
# 3     ADHD Attention Deficit and Hyperactivity Disor...
# ...
